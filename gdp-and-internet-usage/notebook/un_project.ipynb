# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %% [markdown]
# Rows 7662, Columns 4.

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
gdp_df = gdp_df.drop(columns = ['Value Footnotes']).rename(columns = {"Country or Area":"Country", "Year":"Year", "Value":"GDP_Per_Capita"})

# %%
gdp_country_count = gdp_df.Country.value_counts()
gdp_country_count = gdp_country_count.to_frame()
gdp_country_count
# Out:
#                                               count
# Country
# Least developed countries: UN classification     33
# Middle East & North Africa                       33
# Middle East & North Africa (IDA & IBRD)          33
# Middle income                                    33
# Mongolia                                         33
# ...                                             ...
# Kosovo                                           15
# Sint Maarten (Dutch part)                        14
# Turks and Caicos Islands                         12
# Somalia                                          10
# Djibouti                                         10
#
# [242 rows x 1 columns]

# %%
len(gdp_country_count[gdp_country_count['count'] == 33])
# Out:
# 202

# %%
len(gdp_country_count[gdp_country_count['count'] < 33])
# Out:
# 40

# %%
gdp_country_count.tail(40)
# Out:
#                            count
# Country
# Hungary                       32
# Lebanon                       32
# Aruba                         32
# Tonga                         32
# Bhutan                        32
# Slovak Republic               31
# Kuwait                        31
# Turkmenistan                  31
# Cambodia                      30
# West Bank and Gaza            29
# Bosnia and Herzegovina        29
# Latvia                        28
# Israel                        28
# Estonia                       28
# Serbia                        28
# Lithuania                     28
# Iceland                       28
# Moldova                       28
# Maldives                      28
# Croatia                       28
# Slovenia                      28
# Small states                  26
# Montenegro                    26
# San Marino                    25
# Libya                         24
# Timor-Leste                   23
# Liberia                       23
# ...

# %%
observations_by_year = gdp_df.Year.value_counts().to_frame()
observations_by_year
# Out:
#       count
# Year
# 2013    242
# 2016    242
# 2014    242
# 2015    242
# 2020    242
# 2017    242
# 2018    242
# 2019    242
# 2021    241
# 2012    240
# 2011    240
# 2010    239
# 2009    239
# 2008    238
# 2007    237
# 2006    237
# 2004    236
# 2005    236
# 2003    235
# 2002    235
# 2001    234
# 2000    233
# 2022    232
# 1999    227
# 1998    226
# 1997    226
# 1996    223
# 1995    223
# 1994    213
# 1993    211
# 1992    210
# 1991    208
# 1990    207

# %%
observations_by_year = observations_by_year.reset_index()
observations_by_year
# Out:
#     Year  count
# 0   2013    242
# 1   2016    242
# 2   2014    242
# 3   2015    242
# 4   2020    242
# 5   2017    242
# 6   2018    242
# 7   2019    242
# 8   2021    241
# 9   2012    240
# 10  2011    240
# 11  2010    239
# 12  2009    239
# 13  2008    238
# 14  2007    237
# 15  2006    237
# 16  2004    236
# 17  2005    236
# 18  2003    235
# 19  2002    235
# 20  2001    234
# 21  2000    233
# 22  2022    232
# 23  1999    227
# 24  1998    226
# 25  1997    226
# 26  1996    223
# 27  1995    223
# 28  1994    213
# 29  1993    211
# 30  1992    210
# 31  1991    208
# 32  1990    207

# %%
observations_by_year = observations_by_year.sort_values(by = 'Year')
observations_by_year
# Out:
#     Year  count
# 32  1990    207
# 31  1991    208
# 30  1992    210
# 29  1993    211
# 28  1994    213
# 27  1995    223
# 26  1996    223
# 25  1997    226
# 24  1998    226
# 23  1999    227
# 21  2000    233
# 20  2001    234
# 19  2002    235
# 18  2003    235
# 16  2004    236
# 17  2005    236
# 15  2006    237
# 14  2007    237
# 13  2008    238
# 12  2009    239
# 11  2010    239
# 10  2011    240
# 9   2012    240
# 0   2013    242
# 2   2014    242
# 3   2015    242
# 1   2016    242
# 5   2017    242
# 6   2018    242
# 7   2019    242
# 4   2020    242
# 8   2021    241
# 22  2022    232

# %%
plt.plot('Year', 'count', data=observations_by_year)
plt.xlabel('Year')
plt.ylabel('Observations')
# Out:
# Text(0, 0.5, 'Observations')

# %%
twentytwenty_gdp_df = gdp_df.loc[(gdp_df.Year == 2020)]
twentytwenty_gdp_df
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 22    Africa Eastern and Southern  2020     3455.023119
# 55     Africa Western and Central  2020     3957.933804
# 88                        Albania  2020    13278.369769
# 121                       Algeria  2020    10844.770764
# ...                           ...   ...             ...
# 7503                     Viet Nam  2020    10450.622382
# 7536           West Bank and Gaza  2020     5402.538773
# 7565                        World  2020    16204.169107
# 7598                       Zambia  2020     3183.650773
# 7631                     Zimbabwe  2020     1990.319419
#
# [242 rows x 3 columns]

# %%
sns.histplot(twentytwenty_gdp_df.GDP_Per_Capita)
plt.show()

# %%
sns.kdeplot(twentytwenty_gdp_df.GDP_Per_Capita)
plt.show()

# %%
sns.violinplot(twentytwenty_gdp_df['GDP_Per_Capita'])
plt.show()

# %%
sns.boxplot(twentytwenty_gdp_df['GDP_Per_Capita'])
plt.show()

# %%
twentytwenty_gdp_df.GDP_Per_Capita.median()
# Out:
# 13357.997573370474

# %% [markdown]
# 10. For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots:
# 	* A boxplot
# 	* A barplot (check out the Barplot with Seaborn section: https://www.python-graph-gallery.com/barplot/#Seaborn)
# 	* A scatterplot
# 	* A scatterplot with a trend line overlaid (see this regplot example: https://www.python-graph-gallery.com/42-custom-linear-regression-fit-seaborn)
# Comment on what you observe has happened to GDP values over time and the relative strengths and weaknesses of each type of plot.

# %%
gdp_decades = gdp_df.loc[(gdp_df.Year==1990) | (gdp_df.Year==2000) | (gdp_df.Year==2010) | (gdp_df.Year==2020)]
gdp_decades
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 11                    Afghanistan  2010     2026.163818
# 22    Africa Eastern and Southern  2020     3455.023119
# 32    Africa Eastern and Southern  2010     3513.315920
# 42    Africa Eastern and Southern  2000     2897.140841
# ...                           ...   ...             ...
# 7628                       Zambia  1990     2290.039226
# 7631                     Zimbabwe  2020     1990.319419
# 7641                     Zimbabwe  2010     1799.540233
# 7651                     Zimbabwe  2000     2750.601236
# 7661                     Zimbabwe  1990     2704.757299
#
# [921 rows x 3 columns]

# %%
sns.boxplot(data = gdp_decades, x= 'Year', y = 'GDP_Per_Capita');

# %%
sns.barplot(gdp_decades, x='Year', y='GDP_Per_Capita');

# %%
sns.scatterplot(gdp_decades, x='Year', y='GDP_Per_Capita');

# %%
sns.regplot(gdp_decades, x='Year', y='GDP_Per_Capita');

# %% [markdown]
# 11. Which country was the first to have a GDP per capita greater than $100,000?

# %%
gdp_greater_than_100k = gdp_df.loc[gdp_df.GDP_Per_Capita > 100000]
gdp_greater_than_100k.sort_values(by='Year').head(1)
# Out:
#                    Country  Year  GDP_Per_Capita
# 7302  United Arab Emirates  1990   105893.626059

# %% [markdown]
# 12. Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
twentytwenty_gdp_df.sort_values(by='GDP_Per_Capita', ascending=False).head(1)
# Out:
#          Country  Year  GDP_Per_Capita
# 4148  Luxembourg  2020   111751.314751

# %%
luxembourg = gdp_df.loc[gdp_df.Country == 'Luxembourg']

# %%
sns.lineplot(data=luxembourg, x='Year', y='GDP_Per_Capita')
plt.show()

# %% [markdown]
# 13. Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
twentytwenty_gdp_df.sort_values(by='GDP_Per_Capita', ascending=True).head(1)
# Out:
#      Country  Year  GDP_Per_Capita
# 973  Burundi  2020      711.355263

# %%
burundi = gdp_df.loc[gdp_df.Country == 'Burundi']

# %%
sns.lineplot(data=burundi, x='Year', y='GDP_Per_Capita')
plt.show()

# %% [markdown]
# **Bonus question:** Is it true in general that coutries had a higher GDP per capita in 2020 than in 1990? Which countries had lower GDP per capita in 2020 than in 1990?
#
# YES, line 361 shows all the countries

# %%
twentytwenty_gdp_df['GDP_Per_Capita'].mean()
# Out:
# 19586.75444556196

# %%
nineteenninety_gdp_df = gdp_df.loc[(gdp_df.Year == 1990)]
nineteenninety_gdp_df['GDP_Per_Capita'].mean()
# Out:
# 12506.08837386169

# %%
ninety_twenty_df = pd.merge(twentytwenty_gdp_df, nineteenninety_gdp_df, left_on = 'Country', right_on = 'Country', how = 'inner')
ninety_twenty_df
# Out:
#                          Country  Year_x  GDP_Per_Capita_x  Year_y  \
# 0    Africa Eastern and Southern    2020       3455.023119    1990
# 1     Africa Western and Central    2020       3957.933804    1990
# 2                        Albania    2020      13278.369769    1990
# 3                        Algeria    2020      10844.770764    1990
# 4                         Angola    2020       6029.691895    1990
# ..                           ...     ...               ...     ...
# 202                      Vanuatu    2020       2848.970240    1990
# 203                     Viet Nam    2020      10450.622382    1990
# 204                        World    2020      16204.169107    1990
# 205                       Zambia    2020       3183.650773    1990
# 206                     Zimbabwe    2020       1990.319419    1990
#
#      GDP_Per_Capita_y
# 0         3037.297466
# 1         2788.301039
# 2         4827.027705
# 3         8828.874473
# 4         5793.084512
# ...

# %%
ninety_twenty_df['Difference'] = ninety_twenty_df['GDP_Per_Capita_x'].sub(ninety_twenty_df['GDP_Per_Capita_y'])
ninety_twenty_df
# Out:
#                          Country  Year_x  GDP_Per_Capita_x  Year_y  \
# 0    Africa Eastern and Southern    2020       3455.023119    1990
# 1     Africa Western and Central    2020       3957.933804    1990
# 2                        Albania    2020      13278.369769    1990
# 3                        Algeria    2020      10844.770764    1990
# 4                         Angola    2020       6029.691895    1990
# ..                           ...     ...               ...     ...
# 202                      Vanuatu    2020       2848.970240    1990
# 203                     Viet Nam    2020      10450.622382    1990
# 204                        World    2020      16204.169107    1990
# 205                       Zambia    2020       3183.650773    1990
# 206                     Zimbabwe    2020       1990.319419    1990
#
#      GDP_Per_Capita_y   Difference
# 0         3037.297466   417.725653
# 1         2788.301039  1169.632765
# 2         4827.027705  8451.342064
# ...

# %%
ninety_twenty_df.loc[(ninety_twenty_df.Difference < 0)]
# Out:
#                                       Country  Year_x  GDP_Per_Capita_x  \
# 15                                   Barbados    2020      13805.777541
# 25                                     Brunei    2020      61603.550804
# 28                                    Burundi    2020        711.355263
# 34                   Central African Republic    2020        847.765012
# 41                                      Congo    2020       3384.654335
# 45                            Dem. Rep. Congo    2020       1044.071214
# 66   Fragile and conflict affected situations    2020       4357.621312
# 68                                      Gabon    2020      13903.288955
# 76                              Guinea-Bissau    2020       1803.630591
# 78                                      Haiti    2020       2970.462845
# 99                                   Kiribati    2020       1897.061922
# 101                           Kyrgyz Republic    2020       4726.196559
# ...

# %% [markdown]
# 14. Read in the internet use dataset into a DataFrame named `internet_df`. You will likely get errors when doing this. Check the arguments for the read_csv function to find ones that can help correct the errors (https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) Once you are able to read it in, take per a look at the top and bottom few rows to make sure that it has been read in correctly. Also, check the datatypes of the columns.

# %%
internet_df = pd.read_csv('../data/internet_use.csv', nrows = 6083)
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6083 entries, 0 to 6082
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  6083 non-null   object
#  1   Year             6083 non-null   int64
#  2   Value            6083 non-null   float64
#  3   Value Footnotes  2826 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 190.2+ KB

# %% [markdown]
# 15. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'.`

# %%
internet_df = internet_df.drop(columns = 'Value Footnotes')
internet_df
# Out:
#      Country or Area  Year      Value
# 0        Afghanistan  2019  17.600000
# 1        Afghanistan  2018  16.800000
# 2        Afghanistan  2017  13.500000
# 3        Afghanistan  2016  11.000000
# 4        Afghanistan  2015   8.260000
# ...              ...   ...        ...
# 6078        Zimbabwe  1997   0.033080
# 6079        Zimbabwe  1996   0.016790
# 6080        Zimbabwe  1995   0.007684
# 6081        Zimbabwe  1994   0.001739
# 6082        Zimbabwe  1990   0.000000
#
# [6083 rows x 3 columns]

# %%
internet_df = internet_df.rename(columns = {'Country or Area': 'Country', 'Year': 'Year', 'Value': 'Internet_Users_Pct'})
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2019           17.600000
# 1     Afghanistan  2018           16.800000
# 2     Afghanistan  2017           13.500000
# 3     Afghanistan  2016           11.000000
# 4     Afghanistan  2015            8.260000
# ...           ...   ...                 ...
# 6078     Zimbabwe  1997            0.033080
# 6079     Zimbabwe  1996            0.016790
# 6080     Zimbabwe  1995            0.007684
# 6081     Zimbabwe  1994            0.001739
# 6082     Zimbabwe  1990            0.000000
#
# [6083 rows x 3 columns]

# %% [markdown]
# 16. Look at the number of observations in this dataset per year. What do you notice?

# %%
internet_df.Year.value_counts()
# Out:
# Year
# 1990    226
# 2007    217
# 2011    214
# 2008    214
# 2009    214
# 2002    214
# 2006    212
# 2001    212
# 2005    212
# 2004    210
# 2000    210
# 2010    209
# 2012    209
# 2003    208
# 1999    207
# 2016    206
# 2017    205
# 2014    204
# 2015    203
# 2013    203
# 1998    195
# 1997    188
# 2021    186
# 2020    186
# 2019    185
# 2022    184
# 1996    177
# 2018    174
# 1995    141
# 1994     92
# 1993     66
# 1992     50
# 1991     39
# 2023     11
# Name: count, dtype: int64

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6083 entries, 0 to 6082
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             6083 non-null   object
#  1   Year                6083 non-null   int64
#  2   Internet_Users_Pct  6083 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 142.7+ KB

# %% [markdown]
# 17. What is the first year to have a non-zero internet users percentage value?

# %%
non_zero_internet_year = internet_df.loc[internet_df.Internet_Users_Pct > .999]
non_zero_internet_year.sort_values(by='Year').head(1)
# Out:
#      Country  Year  Internet_Users_Pct
# 4196  Norway  1991              1.4074

# %% [markdown]
# 18. How does the distribution of internet users percent differ for 2000 and 2014?

# %%
two_thou_df = internet_df.loc[(internet_df.Year == 2000)]
two_thou_df
# Out:
#                   Country  Year  Internet_Users_Pct
# 42                Albania  2000            0.114097
# 71                Algeria  2000            0.491706
# 100               Andorra  2000           10.538800
# 128                Angola  2000            0.105046
# 150              Anguilla  2000           22.405400
# ...                   ...   ...                 ...
# 5974  Virgin Islands (US)  2000           13.815100
# 5994    Wallis and Futuna  2000            4.768070
# 6017                Yemen  2000            0.082500
# 6045               Zambia  2000            0.191072
# 6075             Zimbabwe  2000            0.401434
#
# [210 rows x 3 columns]

# %%
fourteen_df = internet_df.loc[(internet_df.Year == 2014)]
fourteen_df
# Out:
#                   Country  Year  Internet_Users_Pct
# 5             Afghanistan  2014              7.0000
# 28                Albania  2014             54.3000
# 57                Algeria  2014             29.5000
# 87                Andorra  2014             86.1000
# 114                Angola  2014             21.3623
# ...                   ...   ...                 ...
# 5937             Viet Nam  2014             41.0000
# 5960  Virgin Islands (US)  2014             50.0700
# 6003                Yemen  2014             22.5500
# 6031               Zambia  2014              6.5000
# 6061             Zimbabwe  2014             16.3647
#
# [204 rows x 3 columns]

# %%
two_thou_fourteen_comparison_df = pd.concat([two_thou_df, fourteen_df])
sns.boxplot(data = two_thou_fourteen_comparison_df, x = 'Year', y = 'Internet_Users_Pct')
# Out:
# <Axes: xlabel='Year', ylabel='Internet_Users_Pct'>

# %% [markdown]
# 19. For how many countries was the percentage of internet users below 5% in 2014?

# %%
fourteen_df.loc[fourteen_df.Internet_Users_Pct < 5]
# Out:
#                                Country  Year  Internet_Users_Pct
# 873                            Burundi  2014             1.04239
# 1033          Central African Republic  2014             2.70000
# 1061                              Chad  2014             2.90000
# 1517  Democratic Republic of the Congo  2014             3.00000
# 1782                           Eritrea  2014             0.99000
# 2451                     Guinea-Bissau  2014             3.32000
# 3364                        Madagascar  2014             3.70000
# 4073                             Niger  2014             1.24868
# 5055                           Somalia  2014             1.63000
# 5116                       South Sudan  2014             2.60000

# %% [markdown]
# 20. Merge the two DataFrames to one. Do this in a way that keeps **all rows** from each of the two DataFrames. Call the new DataFrame `gdp_and_internet_use`. Look at the first and last few rows to confirm that it merged correctly.

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df, left_on = ['Country','Year'], right_on = ['Country','Year'], how = 'outer')

# %% [markdown]
# 21. Find the three countries with the highest internet users percentage in 2014. Use a seaborn FacetGrid (https://seaborn.pydata.org/generated/seaborn.FacetGrid.html) to compare how the GDP per capita has changed over time for these three countries. What do you notice?

# %%
fourteen_df = gdp_and_internet_use.loc[(gdp_and_internet_use['Year']==2014)]

# %%
fourteen_df.nlargest(4, 'Internet_Users_Pct')
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3820                      Iceland  2014    50450.741612             98.1580
# 2780  Falkland (Malvinas) Islands  2014             NaN             97.6000
# 794                       Bermuda  2014    77361.104881             96.8000
# 6243                       Norway  2014    62838.515727             96.3005

# %%
three_highest_internet = gdp_and_internet_use.loc[(gdp_and_internet_use.Country == 'Iceland') | (gdp_and_internet_use.Country == 'Norway') | (gdp_and_internet_use.Country == 'Bermuda')]
three_highest_internet
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 770   Bermuda  1990    65961.406278              0.0000
# 771   Bermuda  1991    63958.896254                 NaN
# 772   Bermuda  1992    64385.407410                 NaN
# 773   Bermuda  1993    65967.850014                 NaN
# 774   Bermuda  1994    65904.720421                 NaN
# ...       ...   ...             ...                 ...
# 6247   Norway  2018    64696.490887             96.4917
# 6248   Norway  2019    64983.354208             98.0000
# 6249   Norway  2020    63776.160965             94.6076
# 6250   Norway  2021    65909.003030             99.0000
# 6251   Norway  2022    67462.376446             99.0000
#
# [99 rows x 4 columns]

# %%
g = sns.FacetGrid(three_highest_internet, col='Country', hue='Country')
g.map_dataframe(sns.lineplot, x='Year', y='GDP_Per_Capita')

# %% [markdown]
# 22. Subset `gdp_and_internet_use` to just the year 2014. Save this as a new dataframe named `gdp_and_internet_use_2014`.

# %%
gdp_and_internet_use_2014 = fourteen_df
gdp_and_internet_use_2014
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 14                    Afghanistan  2014     2144.449634              7.0000
# 46    Africa Eastern and Southern  2014     3642.875373                 NaN
# 79     Africa Western and Central  2014     4146.994622                 NaN
# 112                       Albania  2014    11586.817446             54.3000
# 145                       Algeria  2014    11561.259795             29.5000
# ...                           ...   ...             ...                 ...
# 8978           West Bank and Gaza  2014     5967.073437                 NaN
# 9011                        World  2014    15120.730322                 NaN
# 9039                        Yemen  2014             NaN             22.5500
# 9070                       Zambia  2014     3375.941270              6.5000
# 9103                     Zimbabwe  2014     2316.954536             16.3647
#
# [284 rows x 4 columns]

# %% [markdown]
# 23. Create a plot which compares Internet Users Percentage and GDP per Capita for the year 2014. What do you notice from this plot? If you see any unusual points, investigate them.

# %%
sns.regplot(data=gdp_and_internet_use_2014, x='Internet_Users_Pct', y='GDP_Per_Capita')
# Out:
# <Axes: xlabel='Internet_Users_Pct', ylabel='GDP_Per_Capita'>

# %% [markdown]
# 24. **Stretch Question:** Use the `qcut` function from pandas (https://pandas.pydata.org/docs/reference/api/pandas.qcut.html) to divide countries in `gdp_per_capita_2014` into three groups based on their GDP per capita values. Label these groups as "Low", "Medium", and "High". Put these labels in a new column, named "GDP_group".

# %%
gdp_and_internet_use_2014['GDP_group'] = pd.qcut(gdp_and_internet_use_2014['GDP_Per_Capita'], q=3, labels=["Low", "Medium", "High"])
gdp_and_internet_use_2014
# Out:
# C:\Users\maitl\AppData\Local\Temp\ipykernel_12876\3905848855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_and_internet_use_2014['GDP_group'] = pd.qcut(gdp_and_internet_use_2014['GDP_Per_Capita'], q=3, labels=["Low", "Medium", "High"])
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct  \
# 14                    Afghanistan  2014     2144.449634              7.0000
# 46    Africa Eastern and Southern  2014     3642.875373                 NaN
# 79     Africa Western and Central  2014     4146.994622                 NaN
# 112                       Albania  2014    11586.817446             54.3000
# 145                       Algeria  2014    11561.259795             29.5000
# ...

# %% [markdown]
# 25. **Stretch Question:** How does the median internet users percentage compare for the three gdp groups?

# %%
gdp_and_internet_use_2014['Internet_Users_Pct'].groupby(gdp_and_internet_use_2014['GDP_group']).median()
# Out:
# C:\Users\maitl\AppData\Local\Temp\ipykernel_12876\967029739.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gdp_and_internet_use_2014['Internet_Users_Pct'].groupby(gdp_and_internet_use_2014['GDP_group']).median()
# GDP_group
# Low       11.0000
# Medium    45.8752
# High      75.9800
# Name: Internet_Users_Pct, dtype: float64
